# %%
from IPython.parallel import Client
import os

rc=Client()
rc.ids

# %%
dview=rc[:]
dview.scatter('a' , range(12))
dview.get('a')

# %%
# %%px
# #Set up paths, working directory inside IPython
#
# import sys
# import os
# import shutil
#
# #QGIS & executables paths(required)
# sys.path.append('C:\Program Files (x86)\QGIS Wien\lib')
# sys.path.append('C:\Program Files (x86)\QGIS Wien\apps')
# sys.path.append('C:\Program Files (x86)\QGIS Wien\apps\qgis\python')
# sys.path.append('C:\Program Files (x86)\QGIS Wien\apps\qgis\python\plugins')
# sys.path.append('C:\Program Files (x86)\QGIS Wien\apps\qgis\python\plugins\processing')
# sys.path.append('C:\Program Files (x86)\QGIS Wien\bin')
#
# delete_temp = True
#
# #Set working directory
# wd = 'C:/Alex/script/soilm/'
# #wd = 'P:/3_Malaria_Risk/1_Data/6_Temperature/Ale_script/'
#
# #Set input files directory
# smdir="P:/3_Malaria_Risk/1_Data/8_Soil_moisture/"
# % reload_ext rpy2.ipython
#
# os.chdir(wd)
# monthList = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
# month = a[0]
# monthName = monthList[month]
# try:
#     os.mkdir(wd+monthName)
# except WindowsError:
#     print ('Directory already created, it will be deleted at the end of the script if delete_temp is set to True!')
#
# os.chdir(wd+monthName)
# os.getcwd()
#
# #Set temporary folder
# os.environ['TMP']=os.getcwd()
#
#
# import qgis
# import gdal
# from PyQt4.QtCore import QFileInfo,QSettings
# from qgis.analysis import QgsRasterCalculator, QgsRasterCalculatorEntry
# from qgis.core import *
# import qgis.utils
#
#
# #Country name(for output filenames)
# country = 'MDG'
#
# #QGIS path(required)
# #QgsApplication.setPrefixPath('/Applications/QGIS.app/Contents/MacOS',True)
# QgsApplication.setPrefixPath('C:/PROGRA~2/QGISWI~1/apps/qgis', True)
# QgsApplication.initQgis()
#
# import sys, glob
# from qgis.core import *
# from PyQt4.QtGui import *
# app = QApplication([])
#
# # Prepare processing framework
# import processing
# from processing.core.Processing import Processing
# from processing.core.ProcessingConfig import ProcessingConfig
# ProcessingConfig.setSettingValue('OUTPUT_FOLDER',os.getcwd())
# Processing.initialize()
# from processing.tools import *

# %%
# %%px
# os.chdir(wd+monthName)
# monthstr=str(month+1)
# if(month<9):
#     monthstr='0'+str(month+1)
# for file in os.listdir(smdir):
#     if file.endswith(".nc")&file.count("SM_CCI"):
#         uri='NETCDF:"'+smdir+file+'":'+monthstr
#         print(uri)
#         rlayer = QgsRasterLayer(uri)
#         print(rlayer.isValid())
#         shapefilename = 'P:/3_Malaria_Risk/1_Data/5_Admin_Boundaries/MDG_adm/MDG_adm0.shp'
#         fileInfo2 = QFileInfo(shapefilename)
#         baseName2 = fileInfo2.baseName()
#         vlayer1 = QgsVectorLayer(shapefilename, baseName2,'ogr')
#         step1=processing.runalg('gdalogr:warpreproject', rlayer, 'EPSG:4326', 'EPSG:4326', None, None, None, None, None, None, None, None, None, None, None, None, wd+monthName+'/'+file+'step1.tif')
#         step2=processing.runalg('gdalogr:fillnodata', QgsRasterLayer(step1['OUTPUT']), 1000, 0, 1, None, None, wd+monthName+'/'+file+'step2.tif')
#         if(QgsRasterLayer(step2['OUTPUT']).isValid()):
#             out=processing.runalg('gdalogr:cliprasterbymasklayer', QgsRasterLayer(step2['OUTPUT']), vlayer1, None, None, None, None, wd+monthName+'/'+file+'outvecchio.tif')
# os.getcwd()

# %%
# %%px
#
# #STEP 6 exit QGIS and remove temporary files
#
#
# QgsApplication.exitQgis()
# #QgsApplication.quit()
# app.quit()
# #print(os.getcwd())

# %%
# %%px
# if(delete_temp==True):
#     oldwd=os.getcwd()
#     os.chdir(wd)
#     shutil.rmtree(oldwd)
